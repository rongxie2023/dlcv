# %% [markdown]
# <a href="https://colab.research.google.com/github/rongxie2023/dlcv/blob/main/Chapter04/Time_comparison_of_augmentation_scenario.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from torchvision import datasets
import torch
data_folder = '../data/FMNIST' # This can be any directory you want to download FMNIST to
fmnist = datasets.FashionMNIST(data_folder, download=True, train=True)

# %%
tr_images = fmnist.data.numpy()
tr_targets = fmnist.targets

# %%
val_fmnist = datasets.FashionMNIST(data_folder, download=True, train=False)
val_images = val_fmnist.data.numpy()
val_targets = val_fmnist.targets

# %%
from imgaug import augmenters as iaa
aug = iaa.Sequential([
              iaa.Affine(translate_px={'x':(-10,10)}, mode='constant'),
            ])

# %%
# %%time
for i in range(64):
  aug.augment_image(tr_images[i])
# Out:
# CPU times: user 113 ms, sys: 127 μs, total: 113 ms
# Wall time: 110 ms

# %%
# %%time
x = aug.augment_images(tr_images[:64])
# Out:
# CPU times: user 78.6 ms, sys: 518 μs, total: 79.2 ms
# Wall time: 75.5 ms
