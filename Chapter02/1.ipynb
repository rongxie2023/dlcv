# %%
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from torch.utils.data import DataLoader, TensorDataset

# 1. 加载数据集
iris = load_iris()
X = iris.data  # 特征 (150, 4)
y = iris.target  # 标签 (150,)

# 2. 数据预处理
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)  # 标准化特征

# 将数据转换为 PyTorch 张量
X_tensor = torch.tensor(X_scaled, dtype=torch.float32)
y_tensor = torch.tensor(y, dtype=torch.long)

# 划分训练集和测试集
X_train, X_test, y_train, y_test = train_test_split(
    X_tensor, y_tensor, test_size=0.2, random_state=42
)

# 创建数据加载器
train_dataset = TensorDataset(X_train, y_train)
test_dataset = TensorDataset(X_test, y_test)
train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=16, shuffle=False)

# 3. 定义神经网络模型
model = nn.Sequential(
    nn.Linear(4, 16),  # 输入层到隐藏层，4个特征输入，16个神经元
    nn.ReLU(),         # 激活函数
    nn.Linear(16, 8),  # 隐藏层到隐藏层，16个输入，8个神经元
    nn.ReLU(),         # 激活函数
    nn.Linear(8, 3)    # 输出层，3个类别
)

# 4. 定义损失函数和优化器
criterion = nn.CrossEntropyLoss()  # 交叉熵损失函数
optimizer = optim.Adam(model.parameters(), lr=0.01)  # Adam优化器

# 5. 训练模型
num_epochs = 50
for epoch in range(num_epochs):
    model.train()  # 设置模型为训练模式
    running_loss = 0.0
    for inputs, labels in train_loader:
        optimizer.zero_grad()  # 清空梯度
        outputs = model(inputs)  # 前向传播
        loss = criterion(outputs, labels)  # 计算损失
        loss.backward()  # 反向传播
        optimizer.step()  # 更新参数
        running_loss += loss.item()

    print(f"Epoch [{epoch+1}/{num_epochs}], Loss: {running_loss/len(train_loader):.4f}")

# 6. 测试模型
model.eval()  # 设置模型为评估模式
correct = 0
total = 0
with torch.no_grad():  # 不计算梯度
    for inputs, labels in test_loader:
        outputs = model(inputs)
        _, predicted = torch.max(outputs, 1)  # 获取预测类别
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

accuracy = 100 * correct / total
print(f"Test Accuracy: {accuracy:.2f}%")
# Out:
# Epoch [1/50], Loss: 1.0952
# Epoch [2/50], Loss: 0.9596
# Epoch [3/50], Loss: 0.7404
# Epoch [4/50], Loss: 0.5548
# Epoch [5/50], Loss: 0.4779
# Epoch [6/50], Loss: 0.4335
# Epoch [7/50], Loss: 0.3653
# Epoch [8/50], Loss: 0.3145
# Epoch [9/50], Loss: 0.2611
# Epoch [10/50], Loss: 0.2184
# Epoch [11/50], Loss: 0.1782
# Epoch [12/50], Loss: 0.1403
# Epoch [13/50], Loss: 0.1134
# Epoch [14/50], Loss: 0.0873
# Epoch [15/50], Loss: 0.0910
# Epoch [16/50], Loss: 0.0796
# Epoch [17/50], Loss: 0.0666
# Epoch [18/50], Loss: 0.0657
# Epoch [19/50], Loss: 0.0599
# Epoch [20/50], Loss: 0.0582
# Epoch [21/50], Loss: 0.0675
# Epoch [22/50], Loss: 0.0586
# Epoch [23/50], Loss: 0.0791
# Epoch [24/50], Loss: 0.0589
# Epoch [25/50], Loss: 0.0656
# Epoch [26/50], Loss: 0.0600
# Epoch [27/50], Loss: 0.0556
# Epoch [28/50], Loss: 0.0598
# Epoch [29/50], Loss: 0.0646
# Epoch [30/50], Loss: 0.0497
# Epoch [31/50], Loss: 0.0554
# Epoch [32/50], Loss: 0.0640
# Epoch [33/50], Loss: 0.0538
# Epoch [34/50], Loss: 0.0549
# Epoch [35/50], Loss: 0.0483
# Epoch [36/50], Loss: 0.0498
# Epoch [37/50], Loss: 0.0674
# Epoch [38/50], Loss: 0.0450
# Epoch [39/50], Loss: 0.0612
# Epoch [40/50], Loss: 0.0491
# Epoch [41/50], Loss: 0.0482
# Epoch [42/50], Loss: 0.0472
# Epoch [43/50], Loss: 0.0549
# Epoch [44/50], Loss: 0.0515
# Epoch [45/50], Loss: 0.0608
# Epoch [46/50], Loss: 0.0469
# Epoch [47/50], Loss: 0.0508
# Epoch [48/50], Loss: 0.0454
# Epoch [49/50], Loss: 0.0485
# Epoch [50/50], Loss: 0.0520
# Test Accuracy: 100.00%
