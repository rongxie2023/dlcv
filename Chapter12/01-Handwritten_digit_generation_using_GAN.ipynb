# %% [markdown]
# <a href="https://colab.research.google.com/github/PacktPublishing/Modern-Computer-Vision-with-PyTorch-2E/blob/main/Chapter12/Handwritten_digit_generation_using_GAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from torch_snippets import *
from torch_snippets.torch_loader import Report

import torch
import torch.nn as nn
from torch import optim
from torch.utils.data import random_split, Dataset, DataLoader
import matplotlib.pyplot as plt

from torchvision.datasets import MNIST
from torchvision import transforms
from torchvision.utils import make_grid
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(device)
# Out:
# cuda

# %%
from torchvision.datasets import MNIST
from torchvision import transforms

transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize(mean=(0.5,), std=(0.5,))
])

data_loader = torch.utils.data.DataLoader(MNIST('../data/MNIST', train=True, download=True, transform=transform),batch_size=128, shuffle=True, drop_last=True)

# %%
class Discriminator(nn.Module):
    def __init__(self):
        super().__init__()
        self.model = nn.Sequential( 
            nn.Linear(784, 1024),
            nn.LeakyReLU(0.2),
            nn.Dropout(0.3),
            nn.Linear(1024, 512),
            nn.LeakyReLU(0.2),
            nn.Dropout(0.3),
            nn.Linear(512, 256),
            nn.LeakyReLU(0.2),
            nn.Dropout(0.3),
            nn.Linear(256, 1),
            nn.Sigmoid()
        )
    def forward(self, x): return self.model(x)

# %%
# %pip install torch_summary
from torchsummary import summary
discriminator = Discriminator().to(device)
summary(discriminator,torch.zeros(1,784))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ├─Sequential: 1-1                        [-1, 1]                   --
# |    └─Linear: 2-1                       [-1, 1024]                803,840
# |    └─LeakyReLU: 2-2                    [-1, 1024]                --
# |    └─Dropout: 2-3                      [-1, 1024]                --
# |    └─Linear: 2-4                       [-1, 512]                 524,800
# |    └─LeakyReLU: 2-5                    [-1, 512]                 --
# |    └─Dropout: 2-6                      [-1, 512]                 --
# |    └─Linear: 2-7                       [-1, 256]                 131,328
# |    └─LeakyReLU: 2-8                    [-1, 256]                 --
# |    └─Dropout: 2-9                      [-1, 256]                 --
# |    └─Linear: 2-10                      [-1, 1]                   257
# |    └─Sigmoid: 2-11                     [-1, 1]                   --
# ==========================================================================================
# Total params: 1,460,225
# Trainable params: 1,460,225
# Non-trainable params: 0
# Total mult-adds (M): 2.92
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.01
# Params size (MB): 5.57
# Estimated Total Size (MB): 5.59
# ==========================================================================================
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ├─Sequential: 1-1                        [-1, 1]                   --
# |    └─Linear: 2-1                       [-1, 1024]                803,840
# |    └─LeakyReLU: 2-2                    [-1, 1024]                --
# |    └─Dropout: 2-3                      [-1, 1024]                --
# |    └─Linear: 2-4                       [-1, 512]                 524,800
# |    └─LeakyReLU: 2-5                    [-1, 512]                 --
# |    └─Dropout: 2-6                      [-1, 512]                 --
# |    └─Linear: 2-7                       [-1, 256]                 131,328
# |    └─LeakyReLU: 2-8                    [-1, 256]                 --
# |    └─Dropout: 2-9                      [-1, 256]                 --
# |    └─Linear: 2-10                      [-1, 1]                   257
# |    └─Sigmoid: 2-11                     [-1, 1]                   --
# ==========================================================================================
# Total params: 1,460,225
# Trainable params: 1,460,225
# Non-trainable params: 0
# Total mult-adds (M): 2.92
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.01
# Params size (MB): 5.57
# Estimated Total Size (MB): 5.59
# ==========================================================================================

# %%
class Generator(nn.Module):
    def __init__(self):
        super().__init__()
        self.model = nn.Sequential(
            nn.Linear(100, 256),
            nn.LeakyReLU(0.2),
            nn.Linear(256, 512),
            nn.LeakyReLU(0.2),
            nn.Linear(512, 1024),
            nn.LeakyReLU(0.2),
            nn.Linear(1024, 784),
            nn.Tanh()
        )

    def forward(self, x): return self.model(x)

# %%
generator = Generator().to(device)
summary(generator,torch.zeros(1,100))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ├─Sequential: 1-1                        [-1, 784]                 --
# |    └─Linear: 2-1                       [-1, 256]                 25,856
# |    └─LeakyReLU: 2-2                    [-1, 256]                 --
# |    └─Linear: 2-3                       [-1, 512]                 131,584
# |    └─LeakyReLU: 2-4                    [-1, 512]                 --
# |    └─Linear: 2-5                       [-1, 1024]                525,312
# |    └─LeakyReLU: 2-6                    [-1, 1024]                --
# |    └─Linear: 2-7                       [-1, 784]                 803,600
# |    └─Tanh: 2-8                         [-1, 784]                 --
# ==========================================================================================
# Total params: 1,486,352
# Trainable params: 1,486,352
# Non-trainable params: 0
# Total mult-adds (M): 2.97
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.02
# Params size (MB): 5.67
# Estimated Total Size (MB): 5.69
# ==========================================================================================
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ├─Sequential: 1-1                        [-1, 784]                 --
# |    └─Linear: 2-1                       [-1, 256]                 25,856
# |    └─LeakyReLU: 2-2                    [-1, 256]                 --
# |    └─Linear: 2-3                       [-1, 512]                 131,584
# |    └─LeakyReLU: 2-4                    [-1, 512]                 --
# |    └─Linear: 2-5                       [-1, 1024]                525,312
# |    └─LeakyReLU: 2-6                    [-1, 1024]                --
# |    └─Linear: 2-7                       [-1, 784]                 803,600
# |    └─Tanh: 2-8                         [-1, 784]                 --
# ==========================================================================================
# Total params: 1,486,352
# Trainable params: 1,486,352
# Non-trainable params: 0
# Total mult-adds (M): 2.97
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.02
# Params size (MB): 5.67
# Estimated Total Size (MB): 5.69
# ==========================================================================================

# %%
def noise(size):
    n = torch.randn(size, 100)
    return n.to(device)

# %%
def discriminator_train_step(real_data, fake_data):
    d_optimizer.zero_grad()
    prediction_real = discriminator(real_data)
    error_real = loss(prediction_real, torch.ones(len(real_data), 1).to(device))
    error_real.backward()
    prediction_fake = discriminator(fake_data)
    error_fake = loss(prediction_fake, torch.zeros(len(fake_data), 1).to(device))
    error_fake.backward()
    d_optimizer.step()
    return error_real + error_fake

# %%
def generator_train_step(fake_data):
    g_optimizer.zero_grad()
    prediction = discriminator(fake_data)
    error = loss(prediction, torch.ones(len(real_data), 1).to(device))
    error.backward()
    g_optimizer.step()
    return error

# %%
discriminator = Discriminator().to(device)
generator = Generator().to(device)
d_optimizer = optim.Adam(discriminator.parameters(), lr=0.0002)
g_optimizer = optim.Adam(generator.parameters(), lr=0.0002)
loss = nn.BCELoss()
# num_epochs = 200
num_epochs = 100

log = Report(num_epochs)

# %%
for epoch in range(num_epochs):
    N = len(data_loader)
    for i, (images, _) in enumerate(data_loader):
        real_data = images.view(len(images), -1).to(device)
        fake_data = generator(noise(len(real_data))).to(device)
        fake_data = fake_data.detach()
        d_loss = discriminator_train_step(real_data, fake_data)
        fake_data = generator(noise(len(real_data))).to(device)
        g_loss = generator_train_step(fake_data)
        log.record(epoch+(1+i)/N, d_loss=d_loss.item(), g_loss=g_loss.item(), end='\r')
    log.report_avgs(epoch+1)
log.plot_epochs(['d_loss', 'g_loss'])
# Out:
# EPOCH: 1.000  g_loss: 4.640  d_loss: 0.726  (18.44s - 1825.14s remaining))
# EPOCH: 2.000  g_loss: 4.184  d_loss: 0.604  (36.54s - 1790.55s remaining))
# EPOCH: 3.000  g_loss: 2.456  d_loss: 0.886  (54.75s - 1770.09s remaining)
# EPOCH: 4.000  g_loss: 2.682  d_loss: 0.814  (72.90s - 1749.72s remaining)
# EPOCH: 5.000  g_loss: 2.950  d_loss: 0.588  (91.10s - 1730.81s remaining)
# EPOCH: 6.000  g_loss: 3.455  d_loss: 0.384  (109.42s - 1714.27s remaining)
# EPOCH: 7.000  g_loss: 3.833  d_loss: 0.363  (127.71s - 1696.69s remaining)
# EPOCH: 8.000  g_loss: 3.168  d_loss: 0.468  (146.09s - 1680.08s remaining)
# EPOCH: 9.000  g_loss: 3.083  d_loss: 0.451  (164.41s - 1662.36s remaining)
# EPOCH: 10.000  g_loss: 3.037  d_loss: 0.493  (182.85s - 1645.64s remaining)
# EPOCH: 11.000  g_loss: 2.934  d_loss: 0.504  (201.10s - 1627.11s remaining)
# EPOCH: 12.000  g_loss: 2.728  d_loss: 0.581  (219.59s - 1610.34s remaining)
# EPOCH: 13.000  g_loss: 2.450  d_loss: 0.634  (237.85s - 1591.77s remaining)
# EPOCH: 14.000  g_loss: 2.585  d_loss: 0.582  (256.20s - 1573.77s remaining)
# EPOCH: 15.000  g_loss: 2.419  d_loss: 0.636  (274.45s - 1555.20s remaining)
# EPOCH: 16.000  g_loss: 2.284  d_loss: 0.692  (292.61s - 1536.20s remaining)
# EPOCH: 17.000  g_loss: 2.145  d_loss: 0.725  (310.94s - 1518.12s remaining)
# EPOCH: 18.000  g_loss: 2.098  d_loss: 0.729  (329.26s - 1499.96s remaining)
# EPOCH: 19.000  g_loss: 2.099  d_loss: 0.759  (347.57s - 1481.76s remaining)
# EPOCH: 20.000  g_loss: 1.959  d_loss: 0.804  (365.80s - 1463.18s remaining)
# EPOCH: 21.000  g_loss: 1.922  d_loss: 0.795  (384.03s - 1444.70s remaining)
# EPOCH: 22.000  g_loss: 1.906  d_loss: 0.789  (402.30s - 1426.35s remaining)
# EPOCH: 23.000  g_loss: 1.767  d_loss: 0.864  (420.59s - 1408.08s remaining)
# EPOCH: 24.000  g_loss: 1.818  d_loss: 0.838  (439.04s - 1390.29s remaining)
# EPOCH: 25.000  g_loss: 1.729  d_loss: 0.869  (457.20s - 1371.60s remaining)
# EPOCH: 26.000  g_loss: 1.751  d_loss: 0.861  (475.59s - 1353.61s remaining)
# EPOCH: 27.000  g_loss: 1.684  d_loss: 0.897  (493.85s - 1335.23s remaining)
# EPOCH: 28.000  g_loss: 1.642  d_loss: 0.911  (512.04s - 1316.68s remaining)
# EPOCH: 29.000  g_loss: 1.554  d_loss: 0.932  (530.23s - 1298.16s remaining)
# EPOCH: 30.000  g_loss: 1.583  d_loss: 0.930  (548.81s - 1280.56s remaining)
# EPOCH: 31.000  g_loss: 1.486  d_loss: 0.964  (567.23s - 1262.54s remaining)
# EPOCH: 32.000  g_loss: 1.524  d_loss: 0.947  (585.46s - 1244.09s remaining)
# EPOCH: 33.000  g_loss: 1.561  d_loss: 0.949  (603.72s - 1225.74s remaining)
# EPOCH: 34.000  g_loss: 1.594  d_loss: 0.925  (622.01s - 1207.43s remaining)
# EPOCH: 35.000  g_loss: 1.643  d_loss: 0.913  (640.27s - 1189.07s remaining)
# EPOCH: 36.000  g_loss: 1.478  d_loss: 0.975  (658.72s - 1171.06s remaining)
# EPOCH: 37.000  g_loss: 1.419  d_loss: 0.994  (676.92s - 1152.60s remaining)
# EPOCH: 38.000  g_loss: 1.424  d_loss: 0.997  (695.11s - 1134.12s remaining)
# EPOCH: 39.000  g_loss: 1.350  d_loss: 1.025  (713.41s - 1115.84s remaining)
# EPOCH: 40.000  g_loss: 1.344  d_loss: 1.036  (731.79s - 1097.69s remaining)
# EPOCH: 41.000  g_loss: 1.369  d_loss: 1.025  (750.02s - 1079.30s remaining)
# EPOCH: 42.000  g_loss: 1.334  d_loss: 1.047  (768.32s - 1061.02s remaining)
# EPOCH: 43.000  g_loss: 1.302  d_loss: 1.046  (786.66s - 1042.79s remaining)
# EPOCH: 44.000  g_loss: 1.303  d_loss: 1.051  (805.01s - 1024.56s remaining)
# EPOCH: 45.000  g_loss: 1.251  d_loss: 1.072  (823.35s - 1006.32s remaining)
# EPOCH: 46.000  g_loss: 1.275  d_loss: 1.071  (841.66s - 988.03s remaining))
# EPOCH: 47.000  g_loss: 1.261  d_loss: 1.079  (859.93s - 969.71s remaining)
# EPOCH: 48.000  g_loss: 1.240  d_loss: 1.090  (878.12s - 951.30s remaining)
# EPOCH: 49.000  g_loss: 1.229  d_loss: 1.096  (896.40s - 932.98s remaining)
# EPOCH: 50.000  g_loss: 1.252  d_loss: 1.078  (914.62s - 914.62s remaining)
# EPOCH: 51.000  g_loss: 1.183  d_loss: 1.107  (933.15s - 896.56s remaining)
# EPOCH: 52.000  g_loss: 1.214  d_loss: 1.111  (951.73s - 878.52s remaining)
# EPOCH: 53.000  g_loss: 1.222  d_loss: 1.096  (970.28s - 860.44s remaining)
# EPOCH: 54.000  g_loss: 1.204  d_loss: 1.103  (988.82s - 842.33s remaining)
# EPOCH: 55.000  g_loss: 1.224  d_loss: 1.099  (1007.39s - 824.23s remaining)
# EPOCH: 56.000  g_loss: 1.249  d_loss: 1.082  (1025.95s - 806.10s remaining)
# EPOCH: 57.000  g_loss: 1.204  d_loss: 1.100  (1044.50s - 787.96s remaining)
# EPOCH: 58.000  g_loss: 1.142  d_loss: 1.130  (1063.24s - 769.94s remaining)
# EPOCH: 59.000  g_loss: 1.161  d_loss: 1.129  (1080.85s - 751.10s remaining)
# EPOCH: 60.000  g_loss: 1.221  d_loss: 1.112  (1097.33s - 731.55s remaining)
# EPOCH: 61.000  g_loss: 1.239  d_loss: 1.090  (1113.78s - 712.09s remaining)
# EPOCH: 62.000  g_loss: 1.181  d_loss: 1.113  (1130.21s - 692.71s remaining)
# EPOCH: 63.000  g_loss: 1.135  d_loss: 1.137  (1146.64s - 673.42s remaining)
# EPOCH: 64.000  g_loss: 1.125  d_loss: 1.151  (1165.44s - 655.56s remaining)
# EPOCH: 65.000  g_loss: 1.095  d_loss: 1.160  (1183.82s - 637.44s remaining)
# EPOCH: 66.000  g_loss: 1.089  d_loss: 1.163  (1202.36s - 619.40s remaining)
# EPOCH: 67.000  g_loss: 1.090  d_loss: 1.169  (1221.17s - 601.47s remaining)
# EPOCH: 68.000  g_loss: 1.084  d_loss: 1.175  (1239.99s - 583.52s remaining)
# EPOCH: 69.000  g_loss: 1.079  d_loss: 1.169  (1258.07s - 565.22s remaining)
# EPOCH: 70.000  g_loss: 1.108  d_loss: 1.165  (1276.11s - 546.91s remaining)
# EPOCH: 71.000  g_loss: 1.103  d_loss: 1.159  (1294.38s - 528.69s remaining)
# EPOCH: 72.000  g_loss: 1.032  d_loss: 1.200  (1312.67s - 510.48s remaining)
# EPOCH: 73.000  g_loss: 1.059  d_loss: 1.178  (1330.82s - 492.22s remaining)
# EPOCH: 74.000  g_loss: 1.082  d_loss: 1.183  (1348.98s - 473.97s remaining)
# EPOCH: 75.000  g_loss: 1.075  d_loss: 1.180  (1367.44s - 455.81s remaining)
# EPOCH: 76.000  g_loss: 1.097  d_loss: 1.160  (1384.68s - 437.27s remaining)
# EPOCH: 77.000  g_loss: 1.068  d_loss: 1.177  (1401.14s - 418.52s remaining)
# EPOCH: 78.000  g_loss: 1.077  d_loss: 1.181  (1419.29s - 400.31s remaining)
# EPOCH: 79.000  g_loss: 1.077  d_loss: 1.174  (1437.86s - 382.22s remaining)
# EPOCH: 80.000  g_loss: 1.044  d_loss: 1.189  (1456.48s - 364.12s remaining)
# EPOCH: 81.000  g_loss: 1.039  d_loss: 1.195  (1475.02s - 345.99s remaining)
# EPOCH: 82.000  g_loss: 1.028  d_loss: 1.196  (1493.52s - 327.85s remaining)
# EPOCH: 83.000  g_loss: 1.029  d_loss: 1.200  (1512.04s - 309.69s remaining)
# EPOCH: 84.000  g_loss: 1.029  d_loss: 1.205  (1530.61s - 291.54s remaining)
# EPOCH: 85.000  g_loss: 1.034  d_loss: 1.203  (1549.17s - 273.38s remaining)
# EPOCH: 86.000  g_loss: 0.999  d_loss: 1.211  (1567.73s - 255.21s remaining)
# EPOCH: 87.000  g_loss: 1.017  d_loss: 1.215  (1586.28s - 237.03s remaining)
# EPOCH: 88.000  g_loss: 1.031  d_loss: 1.194  (1604.90s - 218.85s remaining)
# EPOCH: 89.000  g_loss: 1.033  d_loss: 1.205  (1623.48s - 200.65s remaining)
# EPOCH: 90.000  g_loss: 1.024  d_loss: 1.200  (1642.05s - 182.45s remaining)
# EPOCH: 91.000  g_loss: 0.995  d_loss: 1.216  (1660.49s - 164.22s remaining)
# EPOCH: 92.000  g_loss: 0.997  d_loss: 1.218  (1679.07s - 146.01s remaining)
# EPOCH: 93.000  g_loss: 1.033  d_loss: 1.213  (1697.62s - 127.78s remaining)
# EPOCH: 94.000  g_loss: 1.037  d_loss: 1.203  (1716.17s - 109.54s remaining)
# EPOCH: 95.000  g_loss: 0.996  d_loss: 1.215  (1734.71s - 91.30s remaining))
# EPOCH: 96.000  g_loss: 1.020  d_loss: 1.203  (1753.38s - 73.06s remaining)
# EPOCH: 97.000  g_loss: 0.975  d_loss: 1.224  (1772.06s - 54.81s remaining)
# EPOCH: 98.000  g_loss: 0.979  d_loss: 1.227  (1790.74s - 36.55s remaining)
# EPOCH: 99.000  g_loss: 0.969  d_loss: 1.239  (1808.92s - 18.27s remaining)
# EPOCH: 100.000  g_loss: 0.962  d_loss: 1.240  (1826.98s - 0.00s remaining)
# 100%|██████████| 201/201 [00:02<00:00, 85.15it/s]

# %%
z = torch.randn(64, 100).to(device)
sample_images = generator(z).data.cpu().view(64, 1, 28, 28)
grid = make_grid(sample_images, nrow=8, normalize=True)
show(grid.cpu().detach().permute(1,2,0), sz=5)
